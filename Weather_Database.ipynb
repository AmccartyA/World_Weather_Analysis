# %%
#Import
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import os
# Import the requests library.
import requests

# Import the API key.
from config import open_weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#Create a set of random lats and long
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
#Create a new list
cities = []
#Identify the nearest city for each latitude and longitude combination
for coords in coordinates:
    city = citipy.nearest_city(coords[0], coords[1]).city_name
    
    #If Unique, add to list
    if city not in cities:
        cities.append(city)
#Print the count
len(cities)
# Out:
# 741

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + open_weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | adrar
# Processing Record 8 of Set 1 | lavrentiya
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | manta
# Processing Record 13 of Set 1 | coihaique
# Processing Record 14 of Set 1 | kavaratti
# Processing Record 15 of Set 1 | kolosovka
# Processing Record 16 of Set 1 | samarai
# Processing Record 17 of Set 1 | bull savanna
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | marrakesh
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | linkoping
# Processing Record 22 of Set 1 | avera
# Processing Record 23 of Set 1 | chokurdakh
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | rosarito
# Processing Record 27 of Set 1 | pierre
# Processing Record 28 of Set 1 | khandbari
# Processing Record 29 of Set 1 | severo-kurilsk
# Processing Record 30 of Set 1 | henties bay
# Processing Record 31 of Set 1 | lermontovka
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | fairbanks
# Processing Record 35 of Set 1 | cap malheureux
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | esperance
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | houma
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | santa maria
# Processing Record 43 of Set 1 | istok
# Processing Record 44 of Set 1 | touros
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | copparo
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | beringovskiy
# Processing Record 50 of Set 1 | kalmunai
# Processing Record 1 of Set 2 | katsuura
# Processing Record 2 of Set 2 | padang
# Processing Record 3 of Set 2 | cayenne
# Processing Record 4 of Set 2 | cabedelo
# Processing Record 5 of Set 2 | limbang
# Processing Record 6 of Set 2 | eura
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | paamiut
# Processing Record 9 of Set 2 | jonkoping
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | sibiti
# Processing Record 12 of Set 2 | biltine
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | oum hadjer
# Processing Record 16 of Set 2 | kavieng
# Processing Record 17 of Set 2 | hovd
# Processing Record 18 of Set 2 | calvinia
# Processing Record 19 of Set 2 | provideniya
# Processing Record 20 of Set 2 | tuatapere
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | nelson bay
# Processing Record 24 of Set 2 | miraflores
# Processing Record 25 of Set 2 | vicuna
# Processing Record 26 of Set 2 | yinchuan
# Processing Record 27 of Set 2 | hirado
# Processing Record 28 of Set 2 | keflavik
# Processing Record 29 of Set 2 | coquimbo
# Processing Record 30 of Set 2 | buraydah
# Processing Record 31 of Set 2 | airai
# Processing Record 32 of Set 2 | cidreira
# Processing Record 33 of Set 2 | ivajlovgrad
# City not found. Skipping...
# Processing Record 34 of Set 2 | port hardy
# Processing Record 35 of Set 2 | saint george
# Processing Record 36 of Set 2 | leningradskiy
# Processing Record 37 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 2 | yeppoon
# Processing Record 39 of Set 2 | balkhash
# Processing Record 40 of Set 2 | vredendal
# Processing Record 41 of Set 2 | khatanga
# Processing Record 42 of Set 2 | alihe
# Processing Record 43 of Set 2 | daru
# Processing Record 44 of Set 2 | vitim
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 2 | te anau
# Processing Record 1 of Set 3 | lebu
# Processing Record 2 of Set 3 | san cristobal
# Processing Record 3 of Set 3 | sitka
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | manjacaze
# Processing Record 6 of Set 3 | norman wells
# Processing Record 7 of Set 3 | kenai
# Processing Record 8 of Set 3 | roebourne
# Processing Record 9 of Set 3 | shelburne
# Processing Record 10 of Set 3 | north bend
# Processing Record 11 of Set 3 | roshchino
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | ponta do sol
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | georgetown
# Processing Record 16 of Set 3 | awbari
# Processing Record 17 of Set 3 | louga
# Processing Record 18 of Set 3 | usinsk
# Processing Record 19 of Set 3 | tazovskiy
# Processing Record 20 of Set 3 | beaufort
# Processing Record 21 of Set 3 | batagay-alyta
# Processing Record 22 of Set 3 | san jose
# Processing Record 23 of Set 3 | sabang
# Processing Record 24 of Set 3 | souillac
# Processing Record 25 of Set 3 | denpasar
# Processing Record 26 of Set 3 | asfi
# Processing Record 27 of Set 3 | auki
# Processing Record 28 of Set 3 | camocim
# Processing Record 29 of Set 3 | ndjole
# Processing Record 30 of Set 3 | faanui
# Processing Record 31 of Set 3 | ruteng
# Processing Record 32 of Set 3 | pitmedden
# Processing Record 33 of Set 3 | ahipara
# Processing Record 34 of Set 3 | kidal
# Processing Record 35 of Set 3 | zapolyarnyy
# Processing Record 36 of Set 3 | pangkalanbuun
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | san patricio
# Processing Record 39 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 3 | hasaki
# Processing Record 41 of Set 3 | saskylakh
# Processing Record 42 of Set 3 | lufilufi
# Processing Record 43 of Set 3 | castro
# Processing Record 44 of Set 3 | tamandare
# Processing Record 45 of Set 3 | sambava
# Processing Record 46 of Set 3 | vostok
# Processing Record 47 of Set 3 | torbay
# Processing Record 48 of Set 3 | aasiaat
# Processing Record 49 of Set 3 | cascais
# Processing Record 50 of Set 3 | east london
# Processing Record 1 of Set 4 | aklavik
# Processing Record 2 of Set 4 | jatai
# Processing Record 3 of Set 4 | jamestown
# Processing Record 4 of Set 4 | nikolskoye
# Processing Record 5 of Set 4 | honningsvag
# Processing Record 6 of Set 4 | keshan
# City not found. Skipping...
# Processing Record 7 of Set 4 | tuktoyaktuk
# Processing Record 8 of Set 4 | san carlos de bariloche
# Processing Record 9 of Set 4 | jalu
# Processing Record 10 of Set 4 | port keats
# Processing Record 11 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 4 | nantucket
# Processing Record 13 of Set 4 | tijuana
# Processing Record 14 of Set 4 | rock sound
# Processing Record 15 of Set 4 | sur
# Processing Record 16 of Set 4 | srednekolymsk
# Processing Record 17 of Set 4 | pangnirtung
# Processing Record 18 of Set 4 | ponta delgada
# Processing Record 19 of Set 4 | sao joao da barra
# Processing Record 20 of Set 4 | kabanjahe
# Processing Record 21 of Set 4 | nome
# Processing Record 22 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 4 | vila
# Processing Record 24 of Set 4 | belmonte
# Processing Record 25 of Set 4 | cururupu
# Processing Record 26 of Set 4 | kilindoni
# Processing Record 27 of Set 4 | iqaluit
# Processing Record 28 of Set 4 | salamanca
# Processing Record 29 of Set 4 | victoria
# Processing Record 30 of Set 4 | brokopondo
# Processing Record 31 of Set 4 | port elizabeth
# Processing Record 32 of Set 4 | half moon bay
# Processing Record 33 of Set 4 | lagoa
# Processing Record 34 of Set 4 | codrington
# Processing Record 35 of Set 4 | klaksvik
# Processing Record 36 of Set 4 | namibe
# Processing Record 37 of Set 4 | sirsa
# Processing Record 38 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 4 | verkhoyansk
# Processing Record 40 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 4 | saint-francois
# Processing Record 42 of Set 4 | guaruja
# Processing Record 43 of Set 4 | borogontsy
# Processing Record 44 of Set 4 | andenes
# Processing Record 45 of Set 4 | nouadhibou
# Processing Record 46 of Set 4 | thinadhoo
# Processing Record 47 of Set 4 | kamaishi
# Processing Record 48 of Set 4 | conde
# Processing Record 49 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 4 | canico
# Processing Record 1 of Set 5 | ajdabiya
# Processing Record 2 of Set 5 | pisco
# Processing Record 3 of Set 5 | noumea
# Processing Record 4 of Set 5 | kathmandu
# Processing Record 5 of Set 5 | haines junction
# Processing Record 6 of Set 5 | bereznehuvate
# Processing Record 7 of Set 5 | ahuimanu
# Processing Record 8 of Set 5 | port augusta
# Processing Record 9 of Set 5 | kulhudhuffushi
# Processing Record 10 of Set 5 | chumikan
# Processing Record 11 of Set 5 | pevek
# Processing Record 12 of Set 5 | rennes
# Processing Record 13 of Set 5 | san policarpo
# Processing Record 14 of Set 5 | tiksi
# Processing Record 15 of Set 5 | yola
# Processing Record 16 of Set 5 | morondava
# Processing Record 17 of Set 5 | russell
# Processing Record 18 of Set 5 | tshikapa
# Processing Record 19 of Set 5 | fereydun kenar
# Processing Record 20 of Set 5 | arraial do cabo
# Processing Record 21 of Set 5 | ixtapa
# Processing Record 22 of Set 5 | capreol
# Processing Record 23 of Set 5 | tucurui
# Processing Record 24 of Set 5 | bengkulu
# Processing Record 25 of Set 5 | tomakomai
# Processing Record 26 of Set 5 | koulamoutou
# Processing Record 27 of Set 5 | marawi
# Processing Record 28 of Set 5 | camacha
# Processing Record 29 of Set 5 | nanortalik
# Processing Record 30 of Set 5 | qaanaaq
# Processing Record 31 of Set 5 | tres arroyos
# Processing Record 32 of Set 5 | letlhakane
# Processing Record 33 of Set 5 | bubaque
# Processing Record 34 of Set 5 | launceston
# Processing Record 35 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 5 | gladstone
# Processing Record 37 of Set 5 | talnakh
# Processing Record 38 of Set 5 | sao filipe
# Processing Record 39 of Set 5 | yarada
# Processing Record 40 of Set 5 | husavik
# Processing Record 41 of Set 5 | caibarien
# Processing Record 42 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 5 | itarema
# Processing Record 44 of Set 5 | port-gentil
# Processing Record 45 of Set 5 | kaman
# Processing Record 46 of Set 5 | luderitz
# Processing Record 47 of Set 5 | qasigiannguit
# Processing Record 48 of Set 5 | cairns
# Processing Record 49 of Set 5 | turukhansk
# Processing Record 50 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 6 | bilma
# Processing Record 2 of Set 6 | ust-kuyga
# Processing Record 3 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 4 of Set 6 | castlemaine
# Processing Record 5 of Set 6 | whitehorse
# Processing Record 6 of Set 6 | lompoc
# Processing Record 7 of Set 6 | nuuk
# Processing Record 8 of Set 6 | teguise
# Processing Record 9 of Set 6 | kargil
# Processing Record 10 of Set 6 | nagato
# Processing Record 11 of Set 6 | urtaaul
# City not found. Skipping...
# Processing Record 12 of Set 6 | bilibino
# Processing Record 13 of Set 6 | lasa
# Processing Record 14 of Set 6 | sao gabriel da cachoeira
# Processing Record 15 of Set 6 | grindavik
# Processing Record 16 of Set 6 | pozega
# Processing Record 17 of Set 6 | acajutla
# Processing Record 18 of Set 6 | dudinka
# Processing Record 19 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 20 of Set 6 | hofn
# Processing Record 21 of Set 6 | progreso
# Processing Record 22 of Set 6 | sokolo
# Processing Record 23 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 24 of Set 6 | sioux lookout
# Processing Record 25 of Set 6 | wittenberge
# Processing Record 26 of Set 6 | laguna
# Processing Record 27 of Set 6 | leh
# Processing Record 28 of Set 6 | hobyo
# Processing Record 29 of Set 6 | sertania
# Processing Record 30 of Set 6 | butaritari
# Processing Record 31 of Set 6 | paka
# Processing Record 32 of Set 6 | ancud
# Processing Record 33 of Set 6 | santa ines
# Processing Record 34 of Set 6 | varhaug
# Processing Record 35 of Set 6 | wau
# Processing Record 36 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 6 | geraldton
# Processing Record 38 of Set 6 | gat
# Processing Record 39 of Set 6 | semey
# Processing Record 40 of Set 6 | sento se
# City not found. Skipping...
# Processing Record 41 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 42 of Set 6 | la asuncion
# Processing Record 43 of Set 6 | lazaro cardenas
# Processing Record 44 of Set 6 | omboue
# Processing Record 45 of Set 6 | carutapera
# Processing Record 46 of Set 6 | mengcheng
# Processing Record 47 of Set 6 | bela
# Processing Record 48 of Set 6 | tanggu
# Processing Record 49 of Set 6 | ribeira grande
# Processing Record 50 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 1 of Set 7 | conceicao do araguaia
# Processing Record 2 of Set 7 | robertsport
# Processing Record 3 of Set 7 | san luis
# Processing Record 4 of Set 7 | barstow
# Processing Record 5 of Set 7 | hami
# Processing Record 6 of Set 7 | saldanha
# Processing Record 7 of Set 7 | kodiak
# Processing Record 8 of Set 7 | aksarka
# Processing Record 9 of Set 7 | chara
# Processing Record 10 of Set 7 | vila franca do campo
# Processing Record 11 of Set 7 | maceio
# Processing Record 12 of Set 7 | vestmannaeyjar
# Processing Record 13 of Set 7 | nemuro
# Processing Record 14 of Set 7 | anori
# Processing Record 15 of Set 7 | saint-augustin
# Processing Record 16 of Set 7 | thayetmyo
# Processing Record 17 of Set 7 | kedrovyy
# Processing Record 18 of Set 7 | devils lake
# Processing Record 19 of Set 7 | qostanay
# Processing Record 20 of Set 7 | bethune
# Processing Record 21 of Set 7 | ciudad bolivar
# Processing Record 22 of Set 7 | port lincoln
# Processing Record 23 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 7 | rudbar
# Processing Record 25 of Set 7 | dikson
# Processing Record 26 of Set 7 | ribas do rio pardo
# Processing Record 27 of Set 7 | concordia
# Processing Record 28 of Set 7 | registro
# Processing Record 29 of Set 7 | fairview
# Processing Record 30 of Set 7 | asheboro
# Processing Record 31 of Set 7 | alofi
# Processing Record 32 of Set 7 | muyezerskiy
# Processing Record 33 of Set 7 | murgab
# Processing Record 34 of Set 7 | kaitangata
# Processing Record 35 of Set 7 | kununurra
# Processing Record 36 of Set 7 | katherine
# Processing Record 37 of Set 7 | bambous virieux
# Processing Record 38 of Set 7 | haapiti
# Processing Record 39 of Set 7 | viedma
# Processing Record 40 of Set 7 | mitu
# Processing Record 41 of Set 7 | wanning
# Processing Record 42 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 7 | zhovtneve
# Processing Record 44 of Set 7 | panjwin
# City not found. Skipping...
# Processing Record 45 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 7 | guaca
# Processing Record 47 of Set 7 | kisesa
# Processing Record 48 of Set 7 | clyde river
# Processing Record 49 of Set 7 | rio gallegos
# Processing Record 50 of Set 7 | toora-khem
# Processing Record 1 of Set 8 | shaowu
# Processing Record 2 of Set 8 | yulara
# Processing Record 3 of Set 8 | ende
# Processing Record 4 of Set 8 | fortuna
# Processing Record 5 of Set 8 | grants pass
# Processing Record 6 of Set 8 | grand gaube
# Processing Record 7 of Set 8 | ambulu
# Processing Record 8 of Set 8 | stryn
# Processing Record 9 of Set 8 | genhe
# Processing Record 10 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 11 of Set 8 | hohhot
# Processing Record 12 of Set 8 | nurota
# Processing Record 13 of Set 8 | aswan
# Processing Record 14 of Set 8 | urusha
# Processing Record 15 of Set 8 | baghdad
# Processing Record 16 of Set 8 | kluang
# Processing Record 17 of Set 8 | srivardhan
# Processing Record 18 of Set 8 | kuusamo
# Processing Record 19 of Set 8 | charters towers
# Processing Record 20 of Set 8 | constitucion
# Processing Record 21 of Set 8 | san pedro
# Processing Record 22 of Set 8 | mastic beach
# Processing Record 23 of Set 8 | mitsamiouli
# Processing Record 24 of Set 8 | vila do maio
# Processing Record 25 of Set 8 | tilichiki
# Processing Record 26 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 27 of Set 8 | ust-ishim
# Processing Record 28 of Set 8 | talaya
# Processing Record 29 of Set 8 | ishinomaki
# Processing Record 30 of Set 8 | lapi
# Processing Record 31 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 8 | isla mujeres
# Processing Record 33 of Set 8 | yar-sale
# Processing Record 34 of Set 8 | seoul
# Processing Record 35 of Set 8 | jewar
# Processing Record 36 of Set 8 | oranjemund
# Processing Record 37 of Set 8 | uvira
# Processing Record 38 of Set 8 | hamilton
# Processing Record 39 of Set 8 | rio grande
# Processing Record 40 of Set 8 | najran
# Processing Record 41 of Set 8 | mehamn
# Processing Record 42 of Set 8 | prado
# Processing Record 43 of Set 8 | severo-yeniseyskiy
# Processing Record 44 of Set 8 | san quintin
# Processing Record 45 of Set 8 | san martin
# Processing Record 46 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 8 | muroto
# Processing Record 48 of Set 8 | medicine hat
# Processing Record 49 of Set 8 | namatanai
# Processing Record 50 of Set 8 | celestun
# Processing Record 1 of Set 9 | korem
# Processing Record 2 of Set 9 | gohand
# Processing Record 3 of Set 9 | fare
# Processing Record 4 of Set 9 | chimbote
# Processing Record 5 of Set 9 | paris
# Processing Record 6 of Set 9 | los llanos de aridane
# Processing Record 7 of Set 9 | komsomolskiy
# Processing Record 8 of Set 9 | camana
# Processing Record 9 of Set 9 | hun
# Processing Record 10 of Set 9 | sorong
# Processing Record 11 of Set 9 | ust-tsilma
# Processing Record 12 of Set 9 | ilulissat
# Processing Record 13 of Set 9 | salym
# Processing Record 14 of Set 9 | bandarbeyla
# Processing Record 15 of Set 9 | nioro
# Processing Record 16 of Set 9 | epe
# Processing Record 17 of Set 9 | staryy nadym
# Processing Record 18 of Set 9 | cabinda
# Processing Record 19 of Set 9 | las palmas
# Processing Record 20 of Set 9 | port blair
# Processing Record 21 of Set 9 | zemio
# Processing Record 22 of Set 9 | wukari
# Processing Record 23 of Set 9 | andilamena
# Processing Record 24 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 9 | sorland
# Processing Record 26 of Set 9 | aquiraz
# Processing Record 27 of Set 9 | praia da vitoria
# Processing Record 28 of Set 9 | atikokan
# Processing Record 29 of Set 9 | dingle
# Processing Record 30 of Set 9 | loa janan
# Processing Record 31 of Set 9 | ures
# Processing Record 32 of Set 9 | calafell
# Processing Record 33 of Set 9 | zhigansk
# Processing Record 34 of Set 9 | victor harbor
# Processing Record 35 of Set 9 | kambove
# Processing Record 36 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 9 | teberda
# Processing Record 38 of Set 9 | rafaela
# Processing Record 39 of Set 9 | waingapu
# Processing Record 40 of Set 9 | townsville
# Processing Record 41 of Set 9 | anadyr
# Processing Record 42 of Set 9 | teknaf
# Processing Record 43 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 44 of Set 9 | ballina
# Processing Record 45 of Set 9 | zhovkva
# Processing Record 46 of Set 9 | katobu
# Processing Record 47 of Set 9 | liwale
# Processing Record 48 of Set 9 | bathsheba
# Processing Record 49 of Set 9 | goderich
# Processing Record 50 of Set 9 | veraval
# Processing Record 1 of Set 10 | dawlatabad
# Processing Record 2 of Set 10 | lata
# Processing Record 3 of Set 10 | bam
# Processing Record 4 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 5 of Set 10 | mount pleasant
# Processing Record 6 of Set 10 | osorno
# Processing Record 7 of Set 10 | kingsville
# Processing Record 8 of Set 10 | shubarkuduk
# Processing Record 9 of Set 10 | ridgecrest
# Processing Record 10 of Set 10 | harper
# Processing Record 11 of Set 10 | huarmey
# Processing Record 12 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 10 | bara
# Processing Record 14 of Set 10 | ketchikan
# Processing Record 15 of Set 10 | fort saint james
# Processing Record 16 of Set 10 | nishihara
# Processing Record 17 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 10 | quatre cocos
# Processing Record 19 of Set 10 | makakilo city
# Processing Record 20 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 10 | terra santa
# Processing Record 22 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 10 | oistins
# Processing Record 24 of Set 10 | brae
# Processing Record 25 of Set 10 | grosseto
# Processing Record 26 of Set 10 | umm kaddadah
# Processing Record 27 of Set 10 | adamas
# Processing Record 28 of Set 10 | namikupa
# Processing Record 29 of Set 10 | omsukchan
# Processing Record 30 of Set 10 | gamba
# Processing Record 31 of Set 10 | great yarmouth
# Processing Record 32 of Set 10 | chapais
# Processing Record 33 of Set 10 | karwar
# Processing Record 34 of Set 10 | kutum
# Processing Record 35 of Set 10 | mar del plata
# Processing Record 36 of Set 10 | tarut
# Processing Record 37 of Set 10 | viseu
# Processing Record 38 of Set 10 | rawson
# Processing Record 39 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 40 of Set 10 | hazorasp
# Processing Record 41 of Set 10 | fohnsdorf
# Processing Record 42 of Set 10 | srono
# Processing Record 43 of Set 10 | matagami
# Processing Record 44 of Set 10 | matara
# Processing Record 45 of Set 10 | evensk
# Processing Record 46 of Set 10 | hirara
# Processing Record 47 of Set 10 | portland
# Processing Record 48 of Set 10 | lae
# Processing Record 49 of Set 10 | ipixuna
# Processing Record 50 of Set 10 | sola
# Processing Record 1 of Set 11 | dondo
# Processing Record 2 of Set 11 | santa cruz
# Processing Record 3 of Set 11 | yima
# Processing Record 4 of Set 11 | mayo
# Processing Record 5 of Set 11 | micheweni
# Processing Record 6 of Set 11 | manaus
# Processing Record 7 of Set 11 | mahebourg
# Processing Record 8 of Set 11 | yelovo
# Processing Record 9 of Set 11 | isangel
# Processing Record 10 of Set 11 | emerald
# Processing Record 11 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 11 | omagh
# Processing Record 13 of Set 11 | aksu
# Processing Record 14 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 11 | getulio vargas
# Processing Record 16 of Set 11 | rabo de peixe
# Processing Record 17 of Set 11 | chernyshevskiy
# Processing Record 18 of Set 11 | bagdarin
# Processing Record 19 of Set 11 | brainerd
# Processing Record 20 of Set 11 | durazno
# Processing Record 21 of Set 11 | zhezkazgan
# Processing Record 22 of Set 11 | havre-saint-pierre
# Processing Record 23 of Set 11 | port macquarie
# Processing Record 24 of Set 11 | longyearbyen
# Processing Record 25 of Set 11 | ornskoldsvik
# Processing Record 26 of Set 11 | vestmanna
# Processing Record 27 of Set 11 | faranah
# Processing Record 28 of Set 11 | chachapoyas
# Processing Record 29 of Set 11 | luanda
# Processing Record 30 of Set 11 | phuket
# Processing Record 31 of Set 11 | sept-iles
# Processing Record 32 of Set 11 | ulladulla
# Processing Record 33 of Set 11 | deputatskiy
# Processing Record 34 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 11 | kruisfontein
# Processing Record 36 of Set 11 | goroka
# Processing Record 37 of Set 11 | cruden bay
# City not found. Skipping...
# Processing Record 38 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 11 | kalemie
# Processing Record 40 of Set 11 | alice springs
# Processing Record 41 of Set 11 | kusa
# Processing Record 42 of Set 11 | high level
# Processing Record 43 of Set 11 | lorengau
# Processing Record 44 of Set 11 | sao bernardo
# Processing Record 45 of Set 11 | gariaband
# Processing Record 46 of Set 11 | am timan
# Processing Record 47 of Set 11 | livingston
# Processing Record 48 of Set 11 | mezen
# Processing Record 49 of Set 11 | nata
# Processing Record 50 of Set 11 | kandry
# Processing Record 1 of Set 12 | casa nova
# Processing Record 2 of Set 12 | corner brook
# Processing Record 3 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 4 of Set 12 | fort-shevchenko
# Processing Record 5 of Set 12 | porto velho
# Processing Record 6 of Set 12 | eureka
# Processing Record 7 of Set 12 | atyrau
# Processing Record 8 of Set 12 | cadillac
# Processing Record 9 of Set 12 | kleck
# City not found. Skipping...
# Processing Record 10 of Set 12 | quelimane
# Processing Record 11 of Set 12 | udachnyy
# Processing Record 12 of Set 12 | gambo
# Processing Record 13 of Set 12 | sungaipenuh
# Processing Record 14 of Set 12 | iquitos
# Processing Record 15 of Set 12 | korla
# Processing Record 16 of Set 12 | lensk
# Processing Record 17 of Set 12 | vardo
# Processing Record 18 of Set 12 | kahului
# Processing Record 19 of Set 12 | dryden
# Processing Record 20 of Set 12 | pasighat
# Processing Record 21 of Set 12 | port hedland
# Processing Record 22 of Set 12 | llangefni
# Processing Record 23 of Set 12 | sampit
# Processing Record 24 of Set 12 | yelizovo
# Processing Record 25 of Set 12 | rafai
# Processing Record 26 of Set 12 | santa rosa
# Processing Record 27 of Set 12 | canoinhas
# Processing Record 28 of Set 12 | guerrero negro
# Processing Record 29 of Set 12 | baijiantan
# Processing Record 30 of Set 12 | bambanglipuro
# Processing Record 31 of Set 12 | ambilobe
# Processing Record 32 of Set 12 | prince george
# Processing Record 33 of Set 12 | himatnagar
# Processing Record 34 of Set 12 | meulaboh
# Processing Record 35 of Set 12 | danielskuil
# Processing Record 36 of Set 12 | narsaq
# Processing Record 37 of Set 12 | wanlaweyn
# Processing Record 38 of Set 12 | teya
# Processing Record 39 of Set 12 | vila velha
# Processing Record 40 of Set 12 | tura
# Processing Record 41 of Set 12 | valverde del camino
# Processing Record 42 of Set 12 | pegnitz
# Processing Record 43 of Set 12 | yenagoa
# Processing Record 44 of Set 12 | andra
# Processing Record 45 of Set 12 | muisne
# Processing Record 46 of Set 12 | forest
# Processing Record 47 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 12 | quesnel
# Processing Record 49 of Set 12 | kardla
# Processing Record 50 of Set 12 | axim
# Processing Record 1 of Set 13 | gisborne
# Processing Record 2 of Set 13 | swarzedz
# Processing Record 3 of Set 13 | aranda de duero
# Processing Record 4 of Set 13 | kulunda
# Processing Record 5 of Set 13 | bonavista
# Processing Record 6 of Set 13 | providencia
# Processing Record 7 of Set 13 | wattegama
# Processing Record 8 of Set 13 | mana
# Processing Record 9 of Set 13 | reconquista
# Processing Record 10 of Set 13 | tobermory
# Processing Record 11 of Set 13 | salalah
# Processing Record 12 of Set 13 | novyy urgal
# Processing Record 13 of Set 13 | pemberton
# Processing Record 14 of Set 13 | phuthaditjhaba
# Processing Record 15 of Set 13 | melbu
# Processing Record 16 of Set 13 | nyurba
# Processing Record 17 of Set 13 | cody
# Processing Record 18 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 19 of Set 13 | konnur
# Processing Record 20 of Set 13 | mogadishu
# Processing Record 21 of Set 13 | cabo san lucas
# Processing Record 22 of Set 13 | san vicente de chucuri
# Processing Record 23 of Set 13 | kyra
# Processing Record 24 of Set 13 | novo aripuana
# Processing Record 25 of Set 13 | green river
# Processing Record 26 of Set 13 | stawell
# Processing Record 27 of Set 13 | safranbolu
# Processing Record 28 of Set 13 | tambopata
# Processing Record 29 of Set 13 | ouadda
# Processing Record 30 of Set 13 | kitimat
# Processing Record 31 of Set 13 | sao jose da coroa grande
# Processing Record 32 of Set 13 | shimoda
# Processing Record 33 of Set 13 | college
# Processing Record 34 of Set 13 | copiapo
# Processing Record 35 of Set 13 | qianan
# Processing Record 36 of Set 13 | havelock
# Processing Record 37 of Set 13 | bontang
# Processing Record 38 of Set 13 | buta
# Processing Record 39 of Set 13 | wilsonville
# Processing Record 40 of Set 13 | lamu
# Processing Record 41 of Set 13 | banda aceh
# Processing Record 42 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 43 of Set 13 | hambantota
# Processing Record 44 of Set 13 | tacna
# Processing Record 45 of Set 13 | rundu
# Processing Record 46 of Set 13 | hauterive
# Processing Record 47 of Set 13 | saint-louis
# Processing Record 48 of Set 13 | conceicao do mato dentro
# Processing Record 49 of Set 13 | shelopugino
# Processing Record 50 of Set 13 | save
# Processing Record 1 of Set 14 | parana
# Processing Record 2 of Set 14 | karratha
# Processing Record 3 of Set 14 | birao
# Processing Record 4 of Set 14 | barra do garcas
# Processing Record 5 of Set 14 | bawku
# Processing Record 6 of Set 14 | yialos
# City not found. Skipping...
# Processing Record 7 of Set 14 | baracoa
# Processing Record 8 of Set 14 | middle island
# Processing Record 9 of Set 14 | biak
# Processing Record 10 of Set 14 | ordzhonikidze
# Processing Record 11 of Set 14 | mahon
# Processing Record 12 of Set 14 | sobolevo
# Processing Record 13 of Set 14 | kurilsk
# Processing Record 14 of Set 14 | yantal
# Processing Record 15 of Set 14 | ormara
# Processing Record 16 of Set 14 | alta gracia
# Processing Record 17 of Set 14 | clinton
# Processing Record 18 of Set 14 | trapani
# Processing Record 19 of Set 14 | venado tuerto
# Processing Record 20 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 21 of Set 14 | chicama
# Processing Record 22 of Set 14 | broome
# Processing Record 23 of Set 14 | vengerovo
# Processing Record 24 of Set 14 | aksum
# Processing Record 25 of Set 14 | kollam
# Processing Record 26 of Set 14 | kenora
# Processing Record 27 of Set 14 | jacareacanga
# Processing Record 28 of Set 14 | benguela
# Processing Record 29 of Set 14 | hlobyne
# Processing Record 30 of Set 14 | sakaiminato
# Processing Record 31 of Set 14 | bajo baudo
# City not found. Skipping...
# Processing Record 32 of Set 14 | tabuk
# Processing Record 33 of Set 14 | leshukonskoye
# Processing Record 34 of Set 14 | bria
# Processing Record 35 of Set 14 | aripuana
# Processing Record 36 of Set 14 | asha
# Processing Record 37 of Set 14 | kedougou
# Processing Record 38 of Set 14 | asyut
# Processing Record 39 of Set 14 | akyab
# Processing Record 40 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 14 | plouzane
# Processing Record 42 of Set 14 | pedernales
# Processing Record 43 of Set 14 | jiuquan
# Processing Record 44 of Set 14 | rocha
# Processing Record 45 of Set 14 | santiago
# Processing Record 46 of Set 14 | garissa
# Processing Record 47 of Set 14 | ostrovnoy
# Processing Record 48 of Set 14 | howard springs
# Processing Record 49 of Set 14 | guanay
# Processing Record 50 of Set 14 | hsintien
# City not found. Skipping...
# Processing Record 1 of Set 15 | kamenka
# Processing Record 2 of Set 15 | khilok
# Processing Record 3 of Set 15 | pimentel
# Processing Record 4 of Set 15 | ayagoz
# Processing Record 5 of Set 15 | stirion
# Processing Record 6 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 8 of Set 15 | joshimath
# Processing Record 9 of Set 15 | governador valadares
# Processing Record 10 of Set 15 | wazzan
# City not found. Skipping...
# Processing Record 11 of Set 15 | suffolk
# Processing Record 12 of Set 15 | heswall
# Processing Record 13 of Set 15 | portales
# Processing Record 14 of Set 15 | kyenjojo
# Processing Record 15 of Set 15 | mount isa
# Processing Record 16 of Set 15 | zhanaozen
# Processing Record 17 of Set 15 | uwayl
# City not found. Skipping...
# Processing Record 18 of Set 15 | qeshm
# Processing Record 19 of Set 15 | solnechnyy
# Processing Record 20 of Set 15 | wewak
# Processing Record 21 of Set 15 | kavaje
# Processing Record 22 of Set 15 | winnemucca
# Processing Record 23 of Set 15 | lund
# Processing Record 24 of Set 15 | itaueira
# Processing Record 25 of Set 15 | tigil
# Processing Record 26 of Set 15 | kihei
# Processing Record 27 of Set 15 | bairiki
# Processing Record 28 of Set 15 | kuah
# Processing Record 29 of Set 15 | tukrah
# Processing Record 30 of Set 15 | marau
# Processing Record 31 of Set 15 | kletskaya
# Processing Record 32 of Set 15 | wiang sa
# Processing Record 33 of Set 15 | mangrol
# Processing Record 34 of Set 15 | vanavara
# Processing Record 35 of Set 15 | safford
# Processing Record 36 of Set 15 | balikpapan
# Processing Record 37 of Set 15 | griffith
# Processing Record 38 of Set 15 | diffa
# Processing Record 39 of Set 15 | darhan
# Processing Record 40 of Set 15 | lyubinskiy
# Processing Record 41 of Set 15 | abnub
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Atuona      PF  -9.8000 -139.0333     77.22        76          20
# 1          Barrow      US  71.2906 -156.7887     35.62        93         100
# 2    Punta Arenas      CL -53.1500  -70.9167     30.31        93           0
# 3  Saint-Philippe      RE -21.3585   55.7679     65.79        85          56
# 4          Bethel      US  41.3712  -73.4140     75.76        66         100
# 5     Yellowknife      CA  62.4560 -114.3525     70.32        52          20
# 6           Adrar      MR  20.5022  -10.0711     97.84        18           5
# 7      Lavrentiya      RU  65.5833 -171.0000     41.45        81          95
# 8            Hilo      US  19.7297 -155.0900     91.27        88         100
# 9    Puerto Ayora      EC  -0.7393  -90.3518     70.56        92         100
#
#    Wind Speed Current Description
# 0       16.06          few clouds
# 1       13.80       moderate rain
# 2       10.36           clear sky
# 3       11.21          light rain
# 4        4.00     overcast clouds
# 5        8.05          few clouds
# 6       10.65           clear sky
# 7       14.61     overcast clouds
# 8        3.44          light rain
# 9        3.00     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
